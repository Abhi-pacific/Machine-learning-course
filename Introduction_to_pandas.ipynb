# %%
import pandas as pd

# %% [markdown]
# # there are 2 data-types

# %%
series = pd.Series(['BWM','Honda','Mercedes'])
series
# Out:
# 0         BWM
# 1       Honda
# 2    Mercedes
# dtype: object

# %% [markdown]
# this this is the 1-dimensional

# %%
colours = pd.Series(['red','black','white'])

# %%
colours
# Out:
# 0      red
# 1    black
# 2    white
# dtype: object

# %% [markdown]
# # Creating the data frame with 2 series

# %%
car_data = pd.DataFrame({'Comany':series,'colour':colours})
car_data
# Out:
#      Comany colour
# 0       BWM    red
# 1     Honda  black
# 2  Mercedes  white

# %% [markdown]
# ## this is how we create a data frame from the series data.

# %%
heart_disease = pd.read_csv('https://raw.githubusercontent.com/mrdbourke/zero-to-mastery-ml/refs/heads/master/data/heart-disease.csv')

# %%
heart_disease

# %% [markdown]
# # Describe

# %%
car_data.describe()

# %%
car_data.dtypes

# %%
car_data.columns

# %%
car_data.info()

# %%
car_sales = pd.read_csv('car-sales.csv')

# %%
car_sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
car_sales.tail()
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 5  Toyota  Green          99213      4  $4,500.00
# 6   Honda   Blue          45698      4  $7,500.00
# 7   Honda   Blue          54738      4  $7,000.00
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %% [markdown]
# # .loc and .iloc

# %%
animals = pd.Series(['cat','dog','bird','panda','sanke'],index=[1,2,3,4,5])

# %%
animals.head()
# Out:
# 1      cat
# 2      dog
# 3     bird
# 4    panda
# 5    sanke
# dtype: object

# %% [markdown]
# ## (iloc refers to the position) and (loc refers to the index)

# %%
animals.loc[3]
# Out:
# 'bird'

# %%
car_sales.loc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
animals.iloc[3]
# Out:
# 'panda'

# %%
pd.crosstab(car_sales['Make'], car_sales['Doors'])
# Out:
# Doors   3  4  5
# Make
# BMW     0  0  1
# Honda   0  3  0
# Nissan  0  2  0
# Toyota  1  3  0

# %% [markdown]
# #groupy by

# %%
car_sales.groupby(['Make']).mean(numeric_only=True)
# Out:
#         Odometer (KM)  Doors
# Make
# BMW      11179.000000   5.00
# Honda    62778.333333   4.00
# Nissan  122347.500000   4.00
# Toyota   85451.250000   3.75
